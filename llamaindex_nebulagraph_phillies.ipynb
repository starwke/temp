# %% [markdown]
# # Querying Philadelphia Phillies with LlamaIndex and NebulaGraph

# %% [markdown]
# ## Installation and Configuration

# %%
# %pip uninstall llama_index

# %%
# %pip install llama_index==0.8.64 ipython-ngql nebula3-python pyvis networkx youtube_transcript_api llama_hub
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama_index==0.8.64 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (0.8.64)
# Requirement already satisfied: ipython-ngql in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (0.13.4)
# Requirement already satisfied: nebula3-python in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (3.8.1)
# Requirement already satisfied: pyvis in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (0.3.2)
# Requirement already satisfied: networkx in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (3.3)
# Requirement already satisfied: youtube_transcript_api in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (0.6.2)
# Collecting llama_hub
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/64/fe/53056ecef5c7666a1a8d1a7ea36a99369a977750ed871e8266d891d56f0c/llama_hub-0.0.79.post1-py3-none-any.whl (103.9 MB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama_index==0.8.64) (2.0.31)
# Requirement already satisfied: aiostream<0.6.0,>=0.5.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (0.5.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (1.2.14)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (2024.6.1)
# Requirement already satisfied: langchain>=0.0.303 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (0.0.342)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (1.6.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (3.8.1)
# Requirement already satisfied: numpy in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (1.35.15)
# Requirement already satisfied: pandas in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (2.2.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (0.9.0)
# Requirement already satisfied: urllib3<2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_index==0.8.64) (1.26.19)
# Requirement already satisfied: Jinja2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (3.1.4)
# Requirement already satisfied: tqdm in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (4.66.4)
# Requirement already satisfied: requests in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (2.32.3)
# Requirement already satisfied: pydantic in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (1.10.8)
# Requirement already satisfied: scipy in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (1.14.0)
# Requirement already satisfied: ipywidgets in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython-ngql) (8.1.3)
# Requirement already satisfied: future>=0.18.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nebula3-python) (1.0.0)
# Requirement already satisfied: httplib2>=0.20.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nebula3-python) (0.22.0)
# Requirement already satisfied: pytz>=2021.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nebula3-python) (2024.1)
# Requirement already satisfied: six>=1.16.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nebula3-python) (1.16.0)
# Requirement already satisfied: httpx>=0.22.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx[http2]>=0.22.0->nebula3-python) (0.27.0)
# Requirement already satisfied: ipython>=5.3.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from pyvis) (8.26.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from pyvis) (3.2.2)
# Requirement already satisfied: html2text in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_hub) (2024.2.26)
# INFO: pip is looking at multiple versions of llama-hub to determine which version is compatible with other requirements. This could take a while.
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0e/c0/e0d4fe4937b319e51f45a3f221a1caa61f3ebace5f740eb0019c17382f83/llama_hub-0.0.79-py3-none-any.whl (103.9 MB)
#      ---------------------------------------- 0.0/103.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/103.9 MB ? eta -:--:--
#      -------------------------------------- 0.0/103.9 MB 393.8 kB/s eta 0:04:24
#      -------------------------------------- 0.1/103.9 MB 585.1 kB/s eta 0:02:58
#      -------------------------------------- 0.2/103.9 MB 985.7 kB/s eta 0:01:46
#      ---------------------------------------- 0.3/103.9 MB 1.3 MB/s eta 0:01:22
#      ---------------------------------------- 0.6/103.9 MB 2.0 MB/s eta 0:00:51
#      ---------------------------------------- 0.6/103.9 MB 2.2 MB/s eta 0:00:47
#      ---------------------------------------- 0.6/103.9 MB 2.2 MB/s eta 0:00:47
#      ---------------------------------------- 0.8/103.9 MB 2.1 MB/s eta 0:00:50
#      ---------------------------------------- 0.9/103.9 MB 1.9 MB/s eta 0:00:54
#       --------------------------------------- 1.4/103.9 MB 2.9 MB/s eta 0:00:36
#       --------------------------------------- 1.7/103.9 MB 3.0 MB/s eta 0:00:35
#      ----------- --------------------------- 29.6/104.2 MB 7.0 MB/s eta 0:00:11
#      ----------- --------------------------- 30.3/104.2 MB 7.0 MB/s eta 0:00:11
#      ----------- --------------------------- 30.6/104.2 MB 6.9 MB/s eta 0:00:11
#      ----------- --------------------------- 30.6/104.2 MB 6.9 MB/s eta 0:00:11
#      ----------- --------------------------- 30.8/104.2 MB 6.4 MB/s eta 0:00:12
#      ----------- --------------------------- 30.8/104.2 MB 6.4 MB/s eta 0:00:12
# ...
#      -------------------------------- ------- 6.0/7.3 MB 6.7 MB/s eta 0:00:01
#      ------------------------------------ --- 6.7/7.3 MB 6.6 MB/s eta 0:00:01
#      ------------------------------------ --- 6.7/7.3 MB 6.6 MB/s eta 0:00:01
#      ------------------------------------ --- 6.7/7.3 MB 6.6 MB/s eta 0:00:01
#      ------------------------------------- -- 6.9/7.3 MB 6.0 MB/s eta 0:00:01
#      ------------------------------------- -- 6.9/7.3 MB 6.0 MB/s eta 0:00:01
#      ------------------------------------- -- 6.9/7.3 MB 6.0 MB/s eta 0:00:01
#      ------------------------------------- -- 6.9/7.3 MB 6.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.3/7.3 MB 5.5 MB/s eta 0:00:00
# Collecting atlassian-python-api (from llama_hub)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/67/90/397deb205af6cde2d08a228a296db88f3cd7259706a693a9cc405a74b6d4/atlassian_python_api-3.41.14-py3-none-any.whl (176 kB)
#      ---------------------------------------- 0.0/177.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/177.0 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/177.0 kB ? eta -:--:--
#      -------------- ---------------------- 71.7/177.0 kB 563.7 kB/s eta 0:00:01
#      -------------- ---------------------- 71.7/177.0 kB 563.7 kB/s eta 0:00:01
#      -------------- ---------------------- 71.7/177.0 kB 563.7 kB/s eta 0:00:01
#      ------------------------------------ 177.0/177.0 kB 712.5 kB/s eta 0:00:00
# Collecting llama_hub
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2e/4b/4ed87f81d804a4589c1a7c03e72d1aed514546ec328c9be84703efcb6192/llama_hub-0.0.45-py3-none-any.whl (3.8 MB)
#      ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#      ----- ---------------------------------- 0.5/3.8 MB 3.4 MB/s eta 0:00:01
#      ------- -------------------------------- 0.7/3.8 MB 4.0 MB/s eta 0:00:01
#      ------- -------------------------------- 0.7/3.8 MB 4.0 MB/s eta 0:00:01
#      ------- -------------------------------- 0.7/3.8 MB 4.0 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.1/3.8 MB 3.4 MB/s eta 0:00:01
#      -------------- ------------------------- 1.4/3.8 MB 4.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.7/3.8 MB 4.5 MB/s eta 0:00:01
#      --------------------- ------------------ 2.1/3.8 MB 4.9 MB/s eta 0:00:01
#      -------------------------- ------------- 2.5/3.8 MB 5.1 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.8/3.8 MB 5.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.8/3.8 MB 5.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.8/3.8 MB 5.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.8/3.8 MB 5.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.8/3.8 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_hub) (6.0.0)
# Requirement already satisfied: retrying in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from llama_hub) (1.3.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from dataclasses-json<0.6.0,>=0.5.7->llama_index==0.8.64) (3.21.3)
# Requirement already satisfied: wrapt<2,>=1.10 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from deprecated>=1.2.9.3->llama_index==0.8.64) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httplib2>=0.20.0->nebula3-python) (3.1.2)
# Requirement already satisfied: anyio in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (3.7.1)
# Requirement already satisfied: certifi in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (1.0.5)
# Requirement already satisfied: idna in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (3.7)
# Requirement already satisfied: sniffio in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.22.0->httpx[http2]>=0.22.0->nebula3-python) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from httpx[http2]>=0.22.0->nebula3-python) (4.1.0)
# Requirement already satisfied: decorator in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: stack-data in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: colorama in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from Jinja2->ipython-ngql) (2.1.5)
# Requirement already satisfied: PyYAML>=5.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain>=0.0.303->llama_index==0.8.64) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain>=0.0.303->llama_index==0.8.64) (3.9.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain>=0.0.303->llama_index==0.8.64) (1.33)
# Requirement already satisfied: langchain-core<0.1,>=0.0.7 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain>=0.0.303->llama_index==0.8.64) (0.0.13)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain>=0.0.303->llama_index==0.8.64) (0.0.92)
# Requirement already satisfied: click in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.8.64) (8.1.7)
# Requirement already satisfied: joblib in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.8.64) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama_index==0.8.64) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from openai>=1.1.0->llama_index==0.8.64) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from requests->ipython-ngql) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama_index==0.8.64) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama_index==0.8.64) (1.0.0)
# Collecting oauthlib (from atlassian-python-api->llama_hub)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      -------- ------------------------------- 30.7/151.7 kB ? eta -:--:--
#      -------- ------------------------------- 30.7/151.7 kB ? eta -:--:--
#      -------- ------------------------------- 30.7/151.7 kB ? eta -:--:--
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/151.7 kB 585.1 kB/s eta 0:00:01
#      ---------------------------------- - 143.4/151.7 kB 125.3 kB/s eta 0:00:01
#      ------------------------------------ 151.7/151.7 kB 131.2 kB/s eta 0:00:00
# Collecting requests-oauthlib (from atlassian-python-api->llama_hub)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting jmespath (from atlassian-python-api->llama_hub)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: beautifulsoup4 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from atlassian-python-api->llama_hub) (4.12.3)
# Requirement already satisfied: comm>=0.1.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipywidgets->ipython-ngql) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipywidgets->ipython-ngql) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from ipywidgets->ipython-ngql) (3.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from pandas->llama_index==0.8.64) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from pandas->llama_index==0.8.64) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama_index==0.8.64) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama_index==0.8.64) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama_index==0.8.64) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama_index==0.8.64) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.303->llama_index==0.8.64) (1.9.4)
# Requirement already satisfied: hyperframe<7,>=6.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.22.0->nebula3-python) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.22.0->nebula3-python) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.303->llama_index==0.8.64) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain-core<0.1,>=0.0.7->langchain>=0.0.303->llama_index==0.8.64) (23.2)
# Requirement already satisfied: wcwidth in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from beautifulsoup4->atlassian-python-api->llama_hub) (2.5)
# Requirement already satisfied: executing>=1.2.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Installing collected packages: oauthlib, jmespath, requests-oauthlib, atlassian-python-api, llama_hub
# Successfully installed atlassian-python-api-3.41.14 jmespath-1.0.1 llama_hub-0.0.45 oauthlib-3.2.2 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import logging
import sys

os.environ["OPENAI_API_KEY"] = "sk-xxx"

# os.environ["OPENAI_API_KEY"] = "sk-xxx"
# os.environ["OPENAI_API_BASE"] =  "xxx"

logging.basicConfig(stream=sys.stdout, level=logging.ERROR)

# %% [markdown]
# ## Connect to Nebula Graph and set up a new space

# %%
os.environ["GRAPHD_HOST"] = "127.0.0.1"
os.environ["NEBULA_USER"] = "xx"
os.environ["NEBULA_PASSWORD"] = "xx" 
os.environ["NEBULA_ADDRESS"] = "127.0.0.1:9669"  

# %reload_ext ngql
connection_string = f"--address {os.environ['GRAPHD_HOST']} --port 9669 --user root --password {os.environ['NEBULA_PASSWORD']}"
# %ngql {connection_string}
# Out:
# Connection Pool Created
#                     Name
# 0  demo_basketballplayer
# 1           phillies_rag

# %%
# %ngql CREATE SPACE IF NOT EXISTS phillies_rag(vid_type=FIXED_STRING(256), partition_num=1, replica_factor=1);
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ngql SHOW SPACES;
# Out:
#                     Name
# 0  demo_basketballplayer
# 1           phillies_rag

# %%
# %%ngql
# USE phillies_rag;
# CREATE TAG IF NOT EXISTS entity(name string);
# CREATE EDGE IF NOT EXISTS relationship(relationship string);
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ngql CREATE TAG INDEX IF NOT EXISTS entity_index ON entity(name(256));
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ngql ALTER TAG entity ADD (column_name_cn string);
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ngql UPDATE VERTEX ON entity resource SET column_name_cn='项目资源';
# Out:
# [ERROR]:
#  Query Failed:
#  SyntaxError: syntax error near `SET'
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ngql LOOKUP ON `entity` WHERE `entity`.name == "resource" YIELD `vid`;
# Out:
# [ERROR]:
#  Query Failed:
#  SemanticError: Invalid label identifiers: vid
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %pip uninstall langchain
# %pip install langchain==0.0.342
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: langchain==0.0.342 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (0.0.342)
# Requirement already satisfied: PyYAML>=5.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (3.9.5)
# Requirement already satisfied: anyio<4.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (0.5.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (1.33)
# Requirement already satisfied: langchain-core<0.1,>=0.0.7 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (0.0.13)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (0.0.92)
# Requirement already satisfied: numpy<2,>=1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (1.10.8)
# Requirement already satisfied: requests<3,>=2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain==0.0.342) (8.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.342) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.342) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.342) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.342) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.342) (1.9.4)
# Requirement already satisfied: idna>=2.8 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from anyio<4.0->langchain==0.0.342) (3.7)
# Requirement already satisfied: sniffio>=1.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from anyio<4.0->langchain==0.0.342) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.342) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.342) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.0.342) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from langchain-core<0.1,>=0.0.7->langchain==0.0.342) (23.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.0.342) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from requests<3,>=2->langchain==0.0.342) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from requests<3,>=2->langchain==0.0.342) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from requests<3,>=2->langchain==0.0.342) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.342) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\project\pythonproject\llamaindex_nebulagraph_phillies\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.342) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.storage.storage_context import StorageContext
from llama_index.graph_stores import NebulaGraphStore

space_name = "phillies_rag"
edge_types, rel_prop_names = ["relationship"], ["relationship"]
tags = ["entity"]

graph_store = NebulaGraphStore(
    space_name=space_name,
    edge_types=edge_types,
    rel_prop_names=rel_prop_names,
    tags=tags,
)
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %%
import langchain as lc

lc.__version__
# Out:
# '0.0.342'

# %% [markdown]
# ## Load data and create KG index

# %%
from llama_index import (
    LLMPredictor,
    ServiceContext,
    KnowledgeGraphIndex,
)
from llama_index.graph_stores import SimpleGraphStore
from llama_index import download_loader
from llama_index.llms import OpenAILike,OpenAI

# define LLM
llm = OpenAI(temperature=0.1, model="gpt-3.5-turbo",)
service_context = ServiceContext.from_defaults(llm=llm, chunk_size=512)

# %%
from llama_index.schema import Document

# %%
import re

def get_documents(directory:str="", include:str="", exclude:str="", drop_head:bool=True) -> list[Document]:
    if not directory:
        print("directory is empty, set it to current path")
        directory = "."
    elif not isinstance(directory, str):
        raise ValueError("directory must be a string")

    if include and not isinstance(include, str):
        raise ValueError("include pattern must be a string")
    if exclude and not isinstance(exclude, str):
        raise ValueError("exclude pattern must be a string")

    path = os.path.abspath(directory)
    if not os.path.exists(path) or not os.path.isdir(path):
        print(f"directory {path} not exist")

    documents = []
    for filename in os.listdir(path):
        # filter filename with include and exclude pattern
        try:
            if include and not re.match(include, filename, flags=re.I):
                continue
        except:
            print(f"invalid include pattern: {include}")

        try:
            if exclude and re.match(exclude, filename, flags=re.I):
                continue
        except:
            print(f"invalid exclude pattern: {exclude}")

        filepath = os.path.join(path, filename)
        if not os.path.isfile(filepath):
            # not a file, skip
            continue

        with open(filepath, "r", encoding="utf8") as f:
            lines = f.readlines()
            if drop_head and len(lines) <= 1:
                print(f"cannot found any valid relationship data from file {filepath}")
                continue
            else:
                documents.append(Document(text="".join(lines[1:])))
                print(f"load file {filepath} successed")

    return documents

# %%
def spilt_text(text: str) -> list[tuple[str, str, str]]:
    if not text or not isinstance(text, str):
        return []

    triplets, lines = [], re.split(r"\n|\\n", text, flags=re.I)
    for line in lines:
        line = line.strip()
        if not line or line.startswith("#") or line.startswith(";"):
            continue

        words = line.strip().split(",", maxsplit=2)
        if len(words) != 3:
            print(f"invalid relationship rows: {text}")
            continue

        row = (words[0].strip(), words[1].strip(), words[2].strip())
        triplets.append(row)

    return triplets

# %%
documents = get_documents(directory="", include="examples_cn.csv")
print(f"Loaded {len(documents)} the relationship between table and columns documents")
# Out:
# directory is empty, set it to current path
# load file e:\Project\pythonProject\llamaindex_nebulagraph_phillies\examples_cn.csv successed
# Loaded 1 the relationship between table and columns documents

# %%
from llama_index import load_index_from_storage
from llama_hub.youtube_transcript import YoutubeTranscriptReader
from llama_hub.wikipedia import WikipediaReader

try:

    storage_context = StorageContext.from_defaults(persist_dir='./storage_graph', graph_store=graph_store)
    kg_index = load_index_from_storage(
        storage_context=storage_context,
        service_context=service_context,
        max_triplets_per_chunk=15,
        space_name=space_name,
        edge_types=edge_types,
        rel_prop_names=rel_prop_names,
        tags=tags,
        verbose=True,
    )
    index_loaded = True
except:
    index_loaded = False

if not index_loaded:

    # WikipediaReader = download_loader("WikipediaReader")
    # loader = WikipediaReader()
    # wiki_documents = loader.load_data(pages=['Philadelphia Phillies'], auto_suggest=False)
    # print(f'Loaded {len(wiki_documents)} documents')

    # youtube_loader = YoutubeTranscriptReader()
    # youtube_documents = youtube_loader.load_data(ytlinks=['https://www.youtube.com/watch?v=k-HTQ8T7oVw'])
    # print(f'Loaded {len(youtube_documents)} YouTube documents')

    kg_index = KnowledgeGraphIndex.from_documents(
        documents=documents,
        storage_context=storage_context,
        max_triplets_per_chunk=15,
        service_context=service_context,
        space_name=space_name,
        edge_types=edge_types,
        rel_prop_names=rel_prop_names,
        tags=tags,
        include_embeddings=True,
        kg_triplet_extract_fn=spilt_text,
    )

    kg_index.storage_context.persist(persist_dir='./storage_graph')

# %% [markdown]
# ## Query with Text2Cypher

# %%
from llama_index.query_engine import KnowledgeGraphQueryEngine
from llama_index.storage.storage_context import StorageContext
from llama_index.graph_stores import NebulaGraphStore
from IPython.display import Markdown, display

# query_engine = KnowledgeGraphQueryEngine(
#     storage_context=storage_context,
#     service_context=service_context,
#     llm=llm,
#     verbose=True,
# )

hybrid_query_engine = kg_index.as_query_engine(
    include_text=True,
    response_mode="tree_summarize",
    embedding_mode="hybrid",
    similarity_top_k=3,
    explore_global_knowledge=True,
)

# %%
hybrid_query_engine = kg_index.as_query_engine()
response = hybrid_query_engine.query("Tell me what columns resource contains")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Resource contains columns for date_month, date_year, and hw_account.</b>

# %%
query_engine = kg_index.as_query_engine()
response = query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 query_engine = kg_index.as_query_engine()
# ----> 2 response = query_engine.query("Tell me about Bryce Harper.")
#       3 display(Markdown(f"<b>{response}</b>"))
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\indices\query\base.py:31, in BaseQueryEngine.query(self, str_or_query_bundle)
#      29 if isinstance(str_or_query_bundle, str):
#      30     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 31 return self._query(str_or_query_bundle)
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\query_engine\retriever_query_engine.py:176, in RetrieverQueryEngine._query(self, query_bundle)
#     169 with self.callback_manager.event(
#     170     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     171 ) as query_event:
#     172     with self.callback_manager.event(
#     173         CBEventType.RETRIEVE,
#     174         payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     175     ) as retrieve_event:
# --> 176         nodes = self.retrieve(query_bundle)
#     178         retrieve_event.on_end(
#     179             payload={EventPayload.NODES: nodes},
#     180         )
#     182     response = self._response_synthesizer.synthesize(
#     183         query=query_bundle,
#     184         nodes=nodes,
#     185     )
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\query_engine\retriever_query_engine.py:128, in RetrieverQueryEngine.retrieve(self, query_bundle)
#     127 def retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
# --> 128     nodes = self._retriever.retrieve(query_bundle)
#     129     return self._apply_node_postprocessors(nodes, query_bundle=query_bundle)
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\indices\base_retriever.py:34, in BaseRetriever.retrieve(self, str_or_query_bundle)
#      32 if isinstance(str_or_query_bundle, str):
#      33     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 34 return self._retrieve(str_or_query_bundle)
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\indices\knowledge_graph\retrievers.py:144, in KGTableRetriever._retrieve(self, query_bundle)
#     142 """Get nodes for response."""
#     143 node_visited = set()
# --> 144 keywords = self._get_keywords(query_bundle.query_str)
#     145 if self._verbose:
#     146     print_text(f"Extracted keywords: {keywords}\n", color="green")
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\indices\knowledge_graph\retrievers.py:119, in KGTableRetriever._get_keywords(self, query_str)
#     117 def _get_keywords(self, query_str: str) -> List[str]:
#     118     """Extract keywords."""
# --> 119     response = self._service_context.llm_predictor.predict(
#     120         self.query_keyword_extract_template,
#     121         max_keywords=self.max_keywords_per_query,
#     122         question=query_str,
#     123     )
#     124     keywords = extract_keywords_given_response(
#     125         response, start_token="KEYWORDS:", lowercase=False
#     126     )
#     127     return list(keywords)
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\llm_predictor\base.py:191, in LLMPredictor.predict(self, prompt, output_cls, **prompt_args)
#     189     messages = prompt.format_messages(llm=self._llm, **prompt_args)
#     190     messages = self._extend_messages(messages)
# --> 191     chat_response = self._llm.chat(messages)
#     192     output = chat_response.message.content or ""
#     193 else:
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\core\llms\callbacks.py:151, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     148 def wrapped_llm_chat(
#     149     _self: Any, messages: Sequence[ChatMessage], **kwargs: Any
#     150 ) -> Any:
# --> 151     with wrapper_logic(_self) as callback_manager:
#     152         span_id = active_span_id.get()
#     153         model_dict = _self.to_dict()
#
# File D:\Softwares\Python3\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File e:\Project\pythonProject\llamaindex_nebulagraph_phillies\.venv\Lib\site-packages\llama_index\core\llms\callbacks.py:45, in llm_chat_callback.<locals>.wrap.<locals>.wrapper_logic(_self)
#      43 callback_manager = getattr(_self, "callback_manager", None)
#      44 if not isinstance(callback_manager, CallbackManager):
# ---> 45     raise ValueError(
#      46         "Cannot use llm_chat_callback on an instance "
#      47         "without a callback_manager attribute."
#      48     )
#      50 yield callback_manager
#
# ValueError: Cannot use llm_chat_callback on an instance without a callback_manager attribute.

# %%
response = query_engine.query("Tell me what columns resource contains")
display(Markdown(f"<b>{response}</b>"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 response = query_engine.query("Tell me what columns resource contains")
#       2 display(Markdown(f"<b>{response}</b>"))
#
# NameError: name 'query_engine' is not defined

# %%
# %%ngql
# MATCH (p:`entity`)-[e:relationship]->(m:`entity`)
#   WHERE p.`entity`.`name` == 'Philadelphia Phillies'
# RETURN p, e, m;
# Out:
# [ERROR]:
#  Query Failed:
#  SemanticError: Space was not chosen.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %ng_draw
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="nebulagraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# <class 'pyvis.network.Network'> |N|=3 |E|=2

# %%
response = query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The impact of the standing ovation Trey Turner received had a positive effect on his season. Following the standing ovation, Trey Turner appeared to be in higher spirits, more at ease, and less burdened by his own thoughts. This translated into improved performance on the field, as evidenced by an increase in his batting average, more successful hits, and a greater number of home runs. The support and admiration displayed by the Philadelphia fans appeared to have bolstered his self-assurance and aided him in overcoming his previous struggles.</b>

# %%
# %%ngql
# MATCH (p:`entity`)-[r:`relationship`]->(q:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner'
# RETURN p, r, q;
# Out:
#                                                p  \
# 0   ("Trey Turner" :entity{name: "Trey Turner"})
# 1   ("Trey Turner" :entity{name: "Trey Turner"})
# 2   ("Trey Turner" :entity{name: "Trey Turner"})
# 3   ("Trey Turner" :entity{name: "Trey Turner"})
# 4   ("Trey Turner" :entity{name: "Trey Turner"})
# ..                                           ...
# 70  ("Trey Turner" :entity{name: "Trey Turner"})
# 71  ("Trey Turner" :entity{name: "Trey Turner"})
# 72  ("Trey Turner" :entity{name: "Trey Turner"})
# 73  ("Trey Turner" :entity{name: "Trey Turner"})
# 74  ("Trey Turner" :entity{name: "Trey Turner"})
#
#                                                     r  \
# 0   ("Trey Turner")-[:relationship@-89965735714464...
# 1   ("Trey Turner")-[:relationship@-89414636367958...
# 2   ("Trey Turner")-[:relationship@-89275189104623...
# 3   ("Trey Turner")-[:relationship@-86268653017792...
# 4   ("Trey Turner")-[:relationship@-86268653017792...
# ..                                                ...
# 70  ("Trey Turner")-[:relationship@804341681940123...
# 71  ("Trey Turner")-[:relationship@859994387799338...
# 72  ("Trey Turner")-[:relationship@859994387799338...
# 73  ("Trey Turner")-[:relationship@878913129174356...
# 74  ("Trey Turner")-[:relationship@887114663913418...
#
#                                                     q
# 0              ("as quick" :entity{name: "as quick"})
# 1   ("a standing ovation" :entity{name: "a standin...
# 2        ("in comments" :entity{name: "in comments"})
# 3                ("25 hits" :entity{name: "25 hits"})
# 4        ("5 home runs" :entity{name: "5 home runs"})
# ..                                                ...
# 70  ("ball and strike call" :entity{name: "ball an...
# 71             ("baseball" :entity{name: "baseball"})
# 72  ("fifth home run" :entity{name: "fifth home ru...
# 73  ("inside of his own head" :entity{name: "insid...
# 74         ("got higher" :entity{name: "got higher"})
#
# [75 rows x 3 columns]

# %%
# %ng_draw
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="nebulagraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# <class 'pyvis.network.Network'> |N|=75 |E|=75

# %%
response = query_engine.query("Tell me about some of the facts of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The Philadelphia Phillies are a professional baseball team based in Philadelphia. They compete in Major League Baseball as a member of the National League East division. The team's home stadium is Citizens Bank Park, located in the South Philadelphia Sports Complex. The Phillies have a rich history, with two World Series championships (in 1980 and 2008), eight National League pennants, and 15 playoff appearances. They have played over 21,000 games since their establishment in 1883, with a record of 10,022 wins and 11,187 losses. The Phillies have had successful periods, including winning 11 division titles and making five consecutive playoff appearances from 2007 to 2011. They have also had notable players, such as Hall of Famers Richie Ashburn and Robin Roberts, as well as recent stars like Bryce Harper, who won the NL Most Valuable Player Award in 2021.</b>

# %%
# %%ngql
# MATCH (p:`entity`)-[e:relationship]->(m:`entity`)
#   WHERE p.`entity`.`name` == 'Philadelphia Phillies'
# RETURN p, e, m;
# Out:
#                                                    p  \
# 0  ("Philadelphia Phillies" :entity{name: "Philad...
# 1  ("Philadelphia Phillies" :entity{name: "Philad...
# 2  ("Philadelphia Phillies" :entity{name: "Philad...
# 3  ("Philadelphia Phillies" :entity{name: "Philad...
# 4  ("Philadelphia Phillies" :entity{name: "Philad...
# 5  ("Philadelphia Phillies" :entity{name: "Philad...
# 6  ("Philadelphia Phillies" :entity{name: "Philad...
# 7  ("Philadelphia Phillies" :entity{name: "Philad...
# 8  ("Philadelphia Phillies" :entity{name: "Philad...
#
#                                                    e  \
# 0  ("Philadelphia Phillies")-[:relationship@-9215...
# 1  ("Philadelphia Phillies")-[:relationship@-8815...
# 2  ("Philadelphia Phillies")-[:relationship@-4023...
# 3  ("Philadelphia Phillies")-[:relationship@14545...
# 4  ("Philadelphia Phillies")-[:relationship@26691...
# 5  ("Philadelphia Phillies")-[:relationship@30666...
# 6  ("Philadelphia Phillies")-[:relationship@42124...
# 7  ("Philadelphia Phillies")-[:relationship@91846...
# 8  ("Philadelphia Phillies")-[:relationship@91846...
#
#                                                    m
# 0       ("Joe Girardi" :entity{name: "Joe Girardi"})
# 1  ("Major League Baseball" :entity{name: "Major ...
# 2  ("15 playoff appearances" :entity{name: "15 pl...
# 3  ("National League" :entity{name: "National Lea...
# 4  ("American professional baseball team" :entity...
# 5  ("Lehigh Valley IronPigs" :entity{name: "Lehig...
# 6     ("Philadelphia" :entity{name: "Philadelphia"})
# 7  ("eight National League pennants" :entity{name...
# 8  ("two World Series championships" :entity{name...

# %%
# %ng_draw
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="nebulagraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# <class 'pyvis.network.Network'> |N|=10 |E|=9

# %% [markdown]
# ## Query with vector index

# %%
from llama_index import VectorStoreIndex

WikipediaReader = download_loader("WikipediaReader")
loader = WikipediaReader()
wiki_documents = loader.load_data(pages=['Philadelphia Phillies'], auto_suggest=False)
print(f'Loaded {len(wiki_documents)} documents')

youtube_loader = YoutubeTranscriptReader()
youtube_documents = youtube_loader.load_data(ytlinks=['https://www.youtube.com/watch?v=k-HTQ8T7oVw'])    
print(f'Loaded {len(youtube_documents)} YouTube documents')

vector_index = VectorStoreIndex.from_documents(wiki_documents + youtube_documents)
vector_query_engine = vector_index.as_query_engine()

response = vector_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Loaded 1 documents
# Loaded 1 YouTube documents
# <b>Bryce Harper is a professional baseball player who has played for the Philadelphia Phillies since the 2019 season. He was signed to a 13-year, $330 million deal, making it one of the biggest contracts in baseball history. Harper has been a key player for the Phillies and has had notable achievements, including winning the NL Most Valuable Player Award for the 2021 season. He has been a significant contributor to the team's success, although they have not yet made the playoffs during his tenure.</b>

# %%
response = vector_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The standing ovation Trey Turner received seemed to have a positive impact on his season. After receiving the ovation, Turner had one of his best games in weeks and felt that the hit he got during that game was one of his best swings all year. In the 18 games since the standing ovation, Turner has been performing well, with a batting average of .343, an OPS over a thousand, and several hits, home runs, and RBIs. The love and support shown by the city of Philadelphia seemed to have boosted Turner's confidence and helped him relax, resulting in improved performance on the field.</b>

# %%
response = vector_query_engine.query("Tell me about some of the facts of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The Philadelphia Phillies are a professional baseball team based in Philadelphia. They compete in Major League Baseball as a member of the National League East division. The team's home stadium is Citizens Bank Park, located in the South Philadelphia Sports Complex. The Phillies have a history dating back to 1883 and have played at several stadiums in the city over the years. They have won two World Series championships, eight National League pennants, and have made 15 playoff appearances. The team has a loyal fan base and is known for its longevity. The Phillies have had both periods of success and periods of futility throughout their history. They were the last of the pre-expansion teams to win a World Series, with their first championship coming in 1980. Since the start of the Divisional Era in 1969, the Phillies have been one of the most successful teams in MLB, winning 11 division titles, eight National League pennants, and two World Series championships. The team's Triple-A affiliate is the Lehigh Valley IronPigs, and their Double-A affiliate is the Reading Fightin Phils. The Phillies' spring training facilities are located in Clearwater, Florida.</b>

# %% [markdown]
# ## Create CustomRetriever to combine vector index and KG index

# %%
from llama_index import QueryBundle
from llama_index.schema import NodeWithScore
from llama_index.retrievers import BaseRetriever, VectorIndexRetriever, KGTableRetriever
from typing import List

class CustomRetriever(BaseRetriever):
    """Custom retriever that performs both Vector search and Knowledge Graph search"""

    def __init__(
        self,
        vector_retriever: VectorIndexRetriever,
        kg_retriever: KGTableRetriever,
        mode: str = "OR",
    ) -> None:
        """Init params."""

        self._vector_retriever = vector_retriever
        self._kg_retriever = kg_retriever
        if mode not in ("AND", "OR"):
            raise ValueError("Invalid mode.")
        self._mode = mode

    def _retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
        """Retrieve nodes given query."""

        vector_nodes = self._vector_retriever.retrieve(query_bundle)
        kg_nodes = self._kg_retriever.retrieve(query_bundle)

        vector_ids = {n.node.node_id for n in vector_nodes}
        kg_ids = {n.node.node_id for n in kg_nodes}

        combined_dict = {n.node.node_id: n for n in vector_nodes}
        combined_dict.update({n.node.node_id: n for n in kg_nodes})

        if self._mode == "AND":
            retrieve_ids = vector_ids.intersection(kg_ids)
        else:
            retrieve_ids = vector_ids.union(kg_ids)

        retrieve_nodes = [combined_dict[rid] for rid in retrieve_ids]
        return retrieve_nodes

# %%
from llama_index import get_response_synthesizer
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.retrievers import VectorIndexRetriever, KGTableRetriever

# create custom retriever
vector_retriever = VectorIndexRetriever(index=vector_index)
kg_retriever = KGTableRetriever(
    index=kg_index, retriever_mode="keyword", include_text=False
)
custom_retriever = CustomRetriever(vector_retriever, kg_retriever)

# create response synthesizer
response_synthesizer = get_response_synthesizer(
    service_context=service_context,
    response_mode="tree_summarize",
)

# %% [markdown]
# ## Create 7 query engines and run queries

# %%
# KG vector-based entity retrieval
kg_query_engine = kg_index.as_query_engine()

# KG keyword-based entity retrieval
kg_keyword_query_engine = kg_index.as_query_engine(
    # setting to false uses the raw triplets instead of adding the text from the corresponding nodes
    include_text=False,
    retriever_mode="keyword",
    response_mode="tree_summarize",
)

# KG hybrid entity retrieval
kg_hybrid_query_engine = kg_index.as_query_engine(
    include_text=True,
    response_mode="tree_summarize",
    embedding_mode="hybrid",
    similarity_top_k=3,
    explore_global_knowledge=True,
)

# Raw vector index retrieval
vector_query_engine = vector_index.as_query_engine()

# Custom combo query engine
custom_query_engine = RetrieverQueryEngine(
    retriever=custom_retriever,
    response_synthesizer=response_synthesizer,
)

# using KnowledgeGraphQueryEngine
from llama_index.query_engine import KnowledgeGraphQueryEngine

kgqe_query_engine = KnowledgeGraphQueryEngine(
    storage_context=storage_context,
    service_context=service_context,
    llm=llm,
    verbose=True,
)

# using KnowledgeGraphRAGRetriever
from llama_index.query_engine import RetrieverQueryEngine
from llama_index.retrievers import KnowledgeGraphRAGRetriever

graph_rag_retriever = KnowledgeGraphRAGRetriever(
    storage_context=storage_context,
    service_context=service_context,
    llm=llm,
    verbose=True,
)

kg_rag_query_engine = RetrieverQueryEngine.from_args(
    graph_rag_retriever, service_context=service_context
)

# %%
response = kg_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Bryce Harper is a baseball player who was named MVP of the NLCS. He also fueled tensions after signing a 13-year $330 million contract.</b>

# %%
response = kg_keyword_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Bryce Harper is a person who has been involved in various relationships and events. He was named MVP of the NLCS and also fueled tensions after signing a 13-year $330 million contract.</b>

# %%
response = kg_hybrid_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Bryce Harper is a star outfielder who has made a significant impact in the world of baseball. He is known for his impressive hitting skills and has been a key player in the lineup of the Philadelphia Phillies. Harper signed a lucrative 13-year, $330 million contract with the Phillies as a free agent in 2019, which has generated some tensions. He was named the MVP of the NLCS and also won the NL Most Valuable Player Award in 2021. Harper's contributions have helped the Phillies reach the playoffs in 2022 and advance to the World Series.</b>

# %%
response = vector_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Bryce Harper is a professional baseball player who has played for the Philadelphia Phillies since the 2019 season. He was signed to a 13-year, $330 million deal, making it one of the biggest contracts in baseball history. Harper has been a key player for the Phillies and has had notable achievements, including winning the NL Most Valuable Player Award for the 2021 season. He has been a significant contributor to the team's success, helping them reach the playoffs in the 2022 season and advancing to the World Series.</b>

# %%
response = custom_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Bryce Harper is a professional baseball player who has played for the Philadelphia Phillies. He joined the team in 2019 after signing a 13-year, $330 million contract, which was a significant move as he was taken away from the division rival Washington Nationals. Harper has been a key player for the Phillies and has had notable achievements during his time with the team. In 2021, he won the NL Most Valuable Player Award. Additionally, Harper played a crucial role in the Phillies' successful 2022 season, where they reached the playoffs for the first time since 2011 and advanced to the World Series. He was named the MVP of the NLCS during that postseason. Overall, Bryce Harper is a highly regarded player who has made a significant impact on the Philadelphia Phillies.</b>

# %%
response = kgqe_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Graph Store Query:
# MATCH (p:`entity`)-[r:`relationship`]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Bryce Harper'
# RETURN e.`entity`.`name`
# Graph Store Response:
# {'e.entity.name': ['13-year $330 million contract', 'NLCS']}
# Final Response: Bryce Harper is associated with a 13-year $330 million contract and the NLCS.
# <b>Bryce Harper is associated with a 13-year $330 million contract and the NLCS.</b>

# %%
response = kg_rag_query_engine.query("Tell me about Bryce Harper.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Entities processed: ['Bryce', 'Harper', 'Bryce Harper']
# Entities processed: ['bryce harper', 'bryce', 'harper']
# Graph RAG context:
# The following are knowledge sequence in max depth 2 in the form of directed graph like:
# `subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...` extracted based on key entities as subject:
# Bryce Harper{name: Bryce Harper} -[relationship:{relationship: was named MVP of}]-> NLCS{name: NLCS}
# Bryce Harper{name: Bryce Harper} -[relationship:{relationship: fueled tensions after signing}]-> 13-year $330 million contract{name: 13-year $330 million contract}
# <b>Bryce Harper is a person who has been involved in various relationships and events.</b>

# %%
response = kg_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The impact of the standing ovation Trey Turner received seemed to have a positive effect on his season. After the ovation, Trey appeared to be in higher spirits and more at ease. This change in mindset translated to his performance on the field, as he played the game with increased confidence. In the games that followed the ovation, Trey displayed impressive stats, including a batting average of .343, five home runs, and 15 RBIs. The support and encouragement from the Philadelphia fans appeared to have revitalized Trey and contributed to his success during that period.</b>

# %%
response = kg_keyword_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The standing ovation Trey Turner received likely had a positive impact on his season.</b>

# %%
response = kg_hybrid_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The standing ovation Trey Turner received had a positive impact on his season. After receiving the ovation, Turner seemed happier, more relaxed, and out of his own head. He started performing better in the games, with improved batting average, more hits, and more home runs. The love and support shown by the fans seemed to have boosted his confidence and helped him get out of his slump. Overall, the standing ovation played a significant role in changing Trey Turner's season for the better.</b>

# %%
response = vector_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The standing ovation Trey Turner received seemed to have a positive impact on his season. After receiving the ovation, Turner had one of his best games in weeks and felt that the hit he got during that game was one of his best swings all year. In the 18 games since the standing ovation, Turner has been performing significantly better, with a batting average of .343, an OPS over a thousand, and multiple hits, home runs, and RBIs. The love and support shown by the Philadelphia fans seemed to have boosted Turner's confidence and helped him relax, resulting in improved performance on the field.</b>

# %%
response = custom_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The standing ovation Trey Turner received had a positive impact on his season. After the ovation, Turner seemed happier, more relaxed, and out of his own head. He started performing better in games, having one of his best games in weeks. He mentioned that the hit he got during that game felt like one of his best swings all year. Since the standing ovation, Turner has been batting with a higher average, hitting more home runs, and driving in more runs. The love and support shown by the city of Philadelphia seemed to have boosted his confidence and helped him get out of his slump. Overall, it appears that the standing ovation boosted Turner's confidence and motivation, leading to a positive change in his season.</b>

# %%
response = kgqe_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Graph Store Query:
# MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`
# ERROR:llama_index.graph_stores.nebulagraph:Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: SyntaxError: syntax error near `MAT'
# ERROR:llama_index.graph_stores.nebulagraph:Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: SyntaxError: syntax error near `MAT'
# ERROR:llama_index.graph_stores.nebulagraph:Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: SyntaxError: syntax error near `MAT'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\graph_stores\nebulagraph.py:300, in NebulaGraphStore.execute(self, query, param_map)
#     296     logger.error(
#     297         f"Query failed. Query: {query}, Param: {param_map}"
#     298         f"Error message: {e}"
#     299     )
# --> 300     raise e
#     301 except Exception as e:
#     302     # other exceptions
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\graph_stores\nebulagraph.py:276, in NebulaGraphStore.execute(self, query, param_map)
#     275 if not result.is_succeeded():
# --> 276     raise ValueError(
#     277         f"Query failed. Query: {query}, Param: {param_map}"
#     278         f"Error message: {result.error_msg()}"
#     279     )
#     280 return result
#
# ValueError: Query failed. Query: MATCH (p:`entity`)-[:relationship]->(e:`entity`)
# WHERE p.`entity`.`name` == 'Trey Turner' AND e.`entity`.`name` == 'season'
# SET p.`entity`.`standing_ovation` = 'changed'
# RETURN p.`entity`.`standing_ovation`, e.`entity`.`name`, Param: {}Error message: SyntaxError: syntax error near `MAT'
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 response = kgqe_query_engine.query("How did the standing ovation Trey Turner received change his season?")
#       2 display(Markdown(f"<b>{response}</b>"))
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\indices\query\base.py:23, in BaseQueryEngine.query(self, str_or_query_bundle)
#      21 if isinstance(str_or_query_bundle, str):
#      22     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 23 response = self._query(str_or_query_bundle)
#      24 return response
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\query_engine\knowledge_graph_query_engine.py:235, in KnowledgeGraphQueryEngine._query(self, query_bundle)
#     231 """Query the graph store."""
#     232 with self.callback_manager.event(
#     233     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     234 ) as query_event:
# --> 235     nodes: List[NodeWithScore] = self._retrieve(query_bundle)
#     237     response = self._response_synthesizer.synthesize(
#     238         query=query_bundle,
#     239         nodes=nodes,
#     240     )
#     242     if self._verbose:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\query_engine\knowledge_graph_query_engine.py:200, in KnowledgeGraphQueryEngine._retrieve(self, query_bundle)
#     193 logger.debug(f"Graph Store Query:\n{graph_store_query}")
#     195 with self.callback_manager.event(
#     196     CBEventType.RETRIEVE,
#     197     payload={EventPayload.QUERY_STR: graph_store_query},
#     198 ) as retrieve_event:
#     199     # Get the graph store response
# --> 200     graph_store_response = self.graph_store.query(query=graph_store_query)
#     201     if self._verbose:
#     202         print_text(
#     203             f"Graph Store Response:\n{graph_store_response}\n",
#     204             color="yellow",
#     205         )
#
# File ~\AppData\Local\anaconda3\lib\site-packages\llama_index\graph_stores\nebulagraph.py:671, in NebulaGraphStore.query(self, query, param_map)
#     670 def query(self, query: str, param_map: Optional[Dict[str, Any]] = {}) -> Any:
# --> 671     result = self.execute(query, param_map)
#     672     columns = result.keys()
#     673     d: Dict[str, list] = {}
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\AppData\Local\anaconda3\lib\site-packages\tenacity\__init__.py:326, in BaseRetrying.iter(self, retry_state)
#     324     if self.reraise:
#     325         raise retry_exc.reraise()
# --> 326     raise retry_exc from fut.exception()
#     328 if self.wait:
#     329     sleep = self.wait(retry_state)
#
# RetryError: RetryError[<Future at 0x27094db1990 state=finished raised ValueError>]

# %%
response = kg_rag_query_engine.query("How did the standing ovation Trey Turner received change his season?")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Entities processed: ['standing', 'Trey Turner', 'Trey', 'ovation', 'season', 'change', 'standing ovation', 'Turner']
# Entities processed: ['standing', 'Trey Turner', 'ovation', 'Trey', 'season', 'change', 'standing ovation', 'Turner']
# Graph RAG context:
# The following are knowledge sequence in max depth 2 in the form of directed graph like:
# `subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...` extracted based on key entities as subject:
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has been stuck}]-> inside of his own head{name: inside of his own head}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has been fighting}]-> his own demons{name: his own demons}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: started out}]-> as good contact hitter{name: as good contact hitter}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: bats}]-> slowed{name: slowed}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has won}]-> World Series{name: World Series}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: figure out}]-> what is wrong with him{name: what is wrong with him}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> two errors{name: two errors}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: hit}]-> baseball{name: baseball}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> one of his best games{name: one of his best games}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: continues on}]-> path to success{name: path to success}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> one home run as a philly{name: one home run as a philly}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> more games as a philly than in the WBC{name: more games as a philly than in the WBC}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> Grand Slam{name: Grand Slam}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> 819 Ops{name: 819 Ops}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> 440 on-base percentage{name: 440 on-base percentage}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> 3.391 batting average{name: 3.391 batting average}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: had}]-> 1.483 Ops{name: 1.483 Ops}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: head}]-> far gone{name: far gone}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: sent}]-> Team USA to championship{name: Team USA to championship}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: change}]-> demand season{name: demand season}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: argued}]-> ball and strike call{name: ball and strike call}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: got ejected}]-> from the game{name: from the game}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has been}]-> on MLB first and second team{name: on MLB first and second team}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has been}]-> Silver Slugger{name: Silver Slugger}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: seemingly was never}]-> going to turn it around{name: going to turn it around}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: is batting}]-> a 3-4-3 batting average{name: a 3-4-3 batting average}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: went into}]-> loan Depot indoor batting cage{name: loan Depot indoor batting cage}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: was able to drive}]-> a fastball{name: a fastball}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: has been stuck inside of}]-> his own head{name: his own head}
# standing ovation{name: standing ovation} <-[relationship:{relationship: look back and say}]- Trey Turner{name: Trey Turner} -[relationship:{relationship: showing}]-> love{name: love}
# <b>The standing ovation Trey Turner received likely had a positive impact on his season.</b>

# %%
response = kg_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The current stadium of the Philadelphia Phillies is Citizens Bank Park. It opened in 2004 and is located in South Philadelphia. The stadium is part of the South Philadelphia Sports Complex, which also includes the Wells Fargo Center and Lincoln Financial Field. Citizens Bank Park replaced Veterans Stadium as the home of the Phillies.</b>

# %%
response = kg_keyword_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The current stadium of the Philadelphia Phillies is known for its unique feature of featuring cardboard figures.</b>

# %%
response = kg_hybrid_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The current stadium of the Philadelphia Phillies is Citizens Bank Park. It has been the team's home stadium since 2004 and is located in the South Philadelphia Sports Complex.</b>

# %%
response = vector_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The current stadium of the Philadelphia Phillies is Citizens Bank Park, which has been their home since 2004. It is located in the South Philadelphia Sports Complex.</b>

# %%
response = custom_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>The current stadium of the Philadelphia Phillies is Citizens Bank Park. It has been the team's home stadium since 2004 and is located in the South Philadelphia Sports Complex. Citizens Bank Park has a restaurant built into the base of the main scoreboard named "Harry the K's" in honor of the late Phillies broadcaster Harry Kalas. The stadium also features a video system that was upgraded in 2011, including a new display screen in left field, which is the largest in the National League at 76 feet high and 97 feet wide.</b>

# %%
response = kgqe_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Graph Store Query:
# MATCH (s:`entity`)-[:`relationship`]->(p:`entity`)
# WHERE s.`name` == 'Philadelphia Phillies'
# RETURN p.`name`
# Graph Store Response:
# {'p.name': []}
# Final Response: I'm sorry, but I couldn't find any facts about the current stadium of the Philadelphia Phillies based on the given context information.
# <b>I'm sorry, but I couldn't find any facts about the current stadium of the Philadelphia Phillies based on the given context information.</b>

# %%
response = kg_rag_query_engine.query("Tell me some facts about the current stadium of Philadelphia Phillies.")
display(Markdown(f"<b>{response}</b>"))
# Out:
# Entities processed: ['Philadelphia', 'stadium', 'current stadium', 'facts', 'current', 'Philadelphia Phillies', 'Phillies']
# Entities processed: ['phillies', 'current stadium', 'Facts', 'facts', 'Phillies', 'philadelphia', 'stadium', 'Philadelphia', 'Stadium', 'current', 'Philadelphia Phillies', 'Current', 'Current stadium']
# Graph RAG context:
# The following are knowledge sequence in max depth 2 in the form of directed graph like:
# `subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...` extracted based on key entities as subject:
# Philadelphia Phillies{name: Philadelphia Phillies} <-[relationship:{relationship: rivalry with}]- Washington Nationals{name: Washington Nationals} -[relationship:{relationship: extends back during}]-> original tenure{name: original tenure}
# Philadelphia Phillies{name: Philadelphia Phillies} <-[relationship:{relationship: rivalry with}]- Washington Nationals{name: Washington Nationals} -[relationship:{relationship: increased in geographic tension due to}]-> proximity to Philadelphia{name: proximity to Philadelphia}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: based in}]-> Philadelphia{name: Philadelphia} <-[relationship:{relationship: for}]- expansion National League franchise{name: expansion National League franchise}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: based in}]-> Philadelphia{name: Philadelphia} <-[relationship:{relationship: moved}]- Toronto Blue Jays{name: Toronto Blue Jays}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: based in}]-> Philadelphia{name: Philadelphia} -[relationship:{relationship: finished}]-> MLB-best record{name: MLB-best record}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: based in}]-> Philadelphia{name: Philadelphia} -[relationship:{relationship: wanted to shed}]-> image of failure{name: image of failure}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: Triple-A affiliate}]-> Lehigh Valley IronPigs{name: Lehigh Valley IronPigs} -[relationship:{relationship: play at}]-> Coca-Cola Park{name: Coca-Cola Park}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: compete in}]-> Major League Baseball{name: Major League Baseball} <-[relationship:{relationship: universally retired by}]- 42{name: 42}
# Philadelphia Phillies{name: Philadelphia Phillies} <-[relationship:{relationship: rivalry with}]- Washington Nationals{name: Washington Nationals}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: won}]-> two World Series championships{name: two World Series championships}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: won}]-> eight National League pennants{name: eight National League pennants}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: are}]-> American professional baseball team{name: American professional baseball team}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: compete in}]-> Major League Baseball{name: Major League Baseball}
# Philadelphia Phillies{name: Philadelphia Phillies} -[relationship:{relationship: based in}]-> Philadelphia{name: Philadelphia} -[relationship:{relationship: should use}]-> blue jay's scientific name{name: blue jay's scientific name}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} <-[relationship:{relationship: trounced}]- A's{name: A's}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} <-[relationship:{relationship: never signed with}]- J. D. Drew{name: J. D. Drew}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} <-[relationship:{relationship: named}]- Baseball America{name: Baseball America}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: won}]-> highest numbers of division championships{name: highest numbers of division championships}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: won}]-> first pennant{name: first pennant}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: won}]-> NLDS three games to one against the Milwaukee Brewers{name: NLDS three games to one against the Milwaukee Brewers}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: won}]-> NL pennant{name: NL pennant}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: faced}]-> Houston Astros{name: Houston Astros}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: continued to contend}]-> next few years{name: next few years}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: defeated}]-> Dodgers in Los Angeles{name: Dodgers in Los Angeles}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: managed to end up in}]-> third place{name: third place}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: finished}]-> two games out of first{name: two games out of first}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: finished}]-> 13 games under .500{name: 13 games under .500}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: clinched}]-> National League East for second year in a row{name: National League East for second year in a row}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: removed the interim role of}]-> Thomson{name: Thomson}
# Philadelphia{name: Philadelphia} <-[relationship:{relationship: founded in}]- Phillies{name: Phillies} -[relationship:{relationship: clinched}]-> National League East{name: National League East}
# <b>The current stadium of the Philadelphia Phillies is not mentioned in the given context information.</b>
